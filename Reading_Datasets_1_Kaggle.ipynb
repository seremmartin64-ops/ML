# %% [markdown]
# <a href="https://colab.research.google.com/github/seremmartin64-ops/ML/blob/main/Reading_Datasets_1_Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
import pandas as pd
import os

# Download latest version
path = kagglehub.dataset_download("tawfikelmetwally/advertising-dataset")

print("Path to dataset files:", path)
print("Files in dataset:", os.listdir(path))

# Use the correct filename
file_path = os.path.join(path, "Advertising.csv")

# Read into pandas DataFrame
df = pd.read_csv(file_path)

df
# Out:
# Using Colab cache for faster access to the 'advertising-dataset' dataset.
# Path to dataset files: /kaggle/input/advertising-dataset
# Files in dataset: ['Advertising.csv']
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# # reading data  on kaggle

# %%
# import libraries needed
# labrary-a file hosted on the internet containing functions for specific task
# Example: django(web development), tensorflow(neural netwoks), kagglehub(kaggle datasets)
import kagglehub
import pandas as pd
import os

# %%
# Download latest version

path = kagglehub.dataset_download("tawfikelmetwally/advertising-dataset")
# Out:
# Using Colab cache for faster access to the 'advertising-dataset' dataset.

# %%
print("Path to dataset files:", path)

print("Files in dataset:", os.listdir(path))
# Out:
# Path to dataset files: /kaggle/input/advertising-dataset
# Files in dataset: ['Advertising.csv']

# %%
file_path = os.path.join(path, "Advertising.csv")

data = pd.read_csv(file_path)

data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
import kagglehub
import pandas as pd
import os

# %%
# Download latest version
path = kagglehub.dataset_download("thedevastator/global-urban-area-indicators")
print( path)
print(os.listdir(path))
# Out:
# ...
# 100%|██████████| 463M/463M [00:06<00:00, 71.7MB/s]
# Extracting files...
# /root/.cache/kagglehub/datasets/thedevastator/global-urban-area-indicators/versions/2
# ['LandCoverData.csv', 'PopulationDensityData.csv', 'TransportData.csv', 'RealEstateData.csv']

# %%
# Join the path and the file needed

file_path = os.path.join(path, "PopulationDensityData.csv")

data = pd.read_csv(file_path)

data
# Out:
#            ID            X            Y         Area         City   Country  \
# 0           1  441387.6502  1019721.213  1013549.420  Addis_Ababa  Ethiopia
# 1           2  442387.6502  1019721.213  1013552.334  Addis_Ababa  Ethiopia
# 2           3  443387.6502  1019721.213  1013555.199  Addis_Ababa  Ethiopia
# 3           4  444387.6502  1019721.213  1013558.013  Addis_Ababa  Ethiopia
# 4           5  445387.6502  1019721.213  1013560.777  Addis_Ababa  Ethiopia
# ...       ...          ...          ...          ...          ...       ...
# 6709159  6972  630002.0000  6133101.000  1005018.000   Montevideo   Uruguay
# 6709160  6973  631002.0000  6133101.000  1005012.000   Montevideo   Uruguay
# 6709161  6974  632002.0000  6133101.000  1005005.000   Montevideo   Uruguay
# 6709162  6975  633002.0000  6133101.000  1004998.000   Montevideo   Uruguay
# 6709163  6976  634002.0000  6133101.000  1004992.000   Montevideo   Uruguay
#
# ...

# %% [markdown]
# # New Section

# %% [markdown]
# World report data  centre

# %%
# world happiness report
import kagglehub
import pandas as pd
import os

# %%
# Download latest version
path = kagglehub.dataset_download("unsdsn/world-happiness")
print( path)
print(os.listdir(path))
# Out:
# Using Colab cache for faster access to the 'world-happiness' dataset.
# /kaggle/input/world-happiness
# ['2015.csv', '2017.csv', '2019.csv', '2018.csv', '2016.csv']

# %%
# Join the path and the file needed

file_path = os.path.join(path, "2019.csv")

data = pd.read_csv(file_path)

data
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
# salesRegression machine learning

# %%
# Machine Learning Regression

# Regression: Used when predicting continous(numerical) outcome

# E,g Sales, Temperature, House Prices, Stock Pric

# Steps follow:

# 1. Read Sales Data From

# 2. Data Cleaning

# 3. Split Data into Inputs(X) and Output(Y)

# 4. Splitting Data into Training Sets(70%) and Testing Sets(30%)

# 5. Importing ML Algorithms(DecisionTree, KNeighbour, SVM) and Training

# 6. Evaluation to Determine Accuracy

# 7. Prediction

# %%
from pathlib import PurePath
# STEP ONE: READING THE DATASET

import kagglehub

import pandas as pd

import os

# Download latest version

path = kagglehub.dataset_download("tawfikelmetwally/advertising-dataset")

print(path)
print(os.listdir(path))
first_path = os.path.join(path, "Advertising.csv")

data = pd.read_csv(first_path)

data
# Out:
# Using Colab cache for faster access to the 'advertising-dataset' dataset.
# /kaggle/input/advertising-dataset
# ['Advertising.csv']
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]
