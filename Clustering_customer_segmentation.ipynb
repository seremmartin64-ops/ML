# %% [markdown]
# <a href="https://colab.research.google.com/github/seremmartin64-ops/ML/blob/main/Clustering_customer_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Unsupervised Machine Learning

# Def: I deal with data without labelled responses and mainly used to find pattern, structures and relationship within data


# Unsupervised Machine Learning

# Def: It deals with data without labelled responses and mainly used to find pattern, structures and relationship within data

# Types of Unsupervised ML

# a) Clustering: Grouping data based on its similar features

# b) Association: One data point is linked with another data point(Apriori Algorithms)

# CLUSTERING

# Customer Segmentation: Grouping customers based on their similar purchasing behaviour.

# %%
import kagglehub
import pandas as pd
import os

path = kagglehub.dataset_download("vjchoudhary7/customer-segmentation-tutorial-in-python")
print(path)
print(os.listdir(path))


file_path = os.path.join(path, "Mall_Customers.csv")
data = pd.read_csv(file_path)
data
# Out:
# Using Colab cache for faster access to the 'customer-segmentation-tutorial-in-python' dataset.
# /kaggle/input/customer-segmentation-tutorial-in-python
# ['Mall_Customers.csv']
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# STEP2: Data Transformation

# Check and Remove Empty/Missing Records

data.isnull().sum() # detect

data.dropna(inplace=True) # remove

# %%
#numbers = [1,2,3,4,5]
#print(numbers[2:5])

# %%
# STEP3: Unsupervised Learning
# Create a variable X to store our Features ONLY, There is no Y
# age,income,spending
array = data.values
array.shape
x = array[:,2:5]
x.shape
# Out:
# (200, 3)

# %%
#K-Means Clustering Algorithm
#K-means is a popular unsupervised machine learning algorithm used for clustering data into groups based on similarity.

#How It Works
#Initialize: Choose K random points as initial cluster centers (centroids)
#Assign: Assign each data point to the nearest centroid
#Update: Recalculate centroids as the mean of all points in each cluster
#Repeat: Continue steps 2-3 until centroids stop moving significantly or max iterations reached

# Step4: Training using KMeans

# Import the Clustering Algorith and Fit the X data

# Here we use the KMeans Algorithm: It clusters groups by the Nearest Mean(K)

from sklearn.cluster import KMeans

model = KMeans(n_clusters=5, random_state=42)

model.fit(X)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
# STEP5: Generate the Clusters Means(K)

centroids = model.cluster_centers_

centroids
# Out:
# array([[ 46.21348315,  47.71910112,  41.79775281],
#        [ 32.45454545, 108.18181818,  82.72727273],
#        [ 24.68965517,  29.5862069 ,  73.65517241],
#        [ 40.39473684,  87.        ,  18.63157895],
#        [ 31.78787879,  76.09090909,  77.75757576]])
